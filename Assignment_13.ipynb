# %% [markdown]
# # ASSIGNMENT 13

# %%
import numpy as np
import pandas as pd
from sqlalchemy import update
from sqlalchemy.orm import sessionmaker
from sqlalchemy.sql import select

# %%
# Read the following data set:
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data

url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
df = pd.read_csv(url)
df.columns=['age','workclass','fnlwgt','education','educationNum','marital_status','occupation','relationship','race','sex','capital_gain','capital_loss','hours_per_week','native_country','income']
df.head()
# Out:
#    age          workclass  fnlwgt   education  educationNum  \
# 0   50   Self-emp-not-inc   83311   Bachelors            13
# 1   38            Private  215646     HS-grad             9
# 2   53            Private  234721        11th             7
# 3   28            Private  338409   Bachelors            13
# 4   37            Private  284582     Masters            14
#
#         marital_status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %%
# Removing all the blank spaces from the columns
def trimAllColumns(df):
    trimStrings = lambda x: x.strip() if type(x) is str else x
    return df.applymap(trimStrings)
df = trimAllColumns(df)
# df.head()

# %%
# Q1. Create an sqlalchemy engine using a sample from the data set

# Taking out a sample from the data
samp = df.sample(n=250)

# Creating an sqlalchemy engine
from sqlalchemy import create_engine
engine = create_engine('sqlite:///:memory:', echo=False)
samp.to_sql('adult_data', con=engine, if_exists='replace',index=True,chunksize = 62)

from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
from sqlalchemy import Column, Integer, String

# Creation of Adult Class
class Adult(Base):
    __tablename__ = 'adult_data'

    index = Column(Integer, primary_key=True)
      
    age = Column(Integer)
    workclass = Column(String)
    fnlwgt = Column(Integer)
    education = Column(String)
    educationNum = Column(Integer)
    marital_status = Column(String)
    occupation = Column(String)
    relationship = Column(String)
    race = Column(String)
    sex = Column(String)
    capital_gain = Column(Integer)
    capital_loss = Column(Integer)
    hours_per_week = Column(Integer)
    native_country = Column(String)
    income = Column(String)

    def __repr__(self):
        return "<Adult(age='{0}', workclass='{1}', fnlwgt='{2}',education='{3}',educationNum='{4}',marital_status='{5}',occupation='{6}',relationship='{7}',race='{8}',sex='{9}',capital_gain='{10}',capital_loss='{11}',hours_per_week='{12}',native_country,income='{13}')>".format(self.age,self.workclass,self.fnlwgt,self.education,self.educationNum,self.marital_status,self.occupation,self.relationship,self.race,self.sex,self.capital_gain,self.capital_loss,self.hours_per_week,self.native_country,self.income)

# Initiating a session
Session = sessionmaker()
Session.configure(bind=engine)
session = Session()

for adult in session.query(Adult):
     print(adult)
# Out:
# <Adult(age='36', workclass='Federal-gov', fnlwgt='68781',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Adm-clerical',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='35',native_country,income='United-States')>
# <Adult(age='62', workclass='?', fnlwgt='199198',education='11th',educationNum='7',marital_status='Divorced',occupation='?',relationship='Not-in-family',race='Black',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='22', workclass='Private', fnlwgt='219086',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Sales',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='55',native_country,income='United-States')>
# <Adult(age='38', workclass='Local-gov', fnlwgt='287658',education='Masters',educationNum='14',marital_status='Divorced',occupation='Prof-specialty',relationship='Not-in-family',race='Black',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='Jamaica')>
# <Adult(age='18', workclass='Private', fnlwgt='243900',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Adm-clerical',relationship='Own-child',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='15',native_country,income='United-States')>
# <Adult(age='39', workclass='?', fnlwgt='361838',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='?',relationship='Wife',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='6',native_country,income='United-States')>
# <Adult(age='45', workclass='Private', fnlwgt='513660',education='Bachelors',educationNum='13',marital_status='Never-married',occupation='Prof-specialty',relationship='Not-in-family',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='55', workclass='Private', fnlwgt='266343',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Prof-specialty',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='46',native_country,income='United-States')>
# <Adult(age='28', workclass='Private', fnlwgt='132686',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='55',native_country,income='United-States')>
# <Adult(age='22', workclass='Local-gov', fnlwgt='289982',education='Bachelors',educationNum='13',marital_status='Never-married',occupation='Prof-specialty',relationship='Own-child',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='35',native_country,income='United-States')>
# <Adult(age='22', workclass='State-gov', fnlwgt='309348',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Adm-clerical',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='15',native_country,income='United-States')>
# <Adult(age='23', workclass='Private', fnlwgt='206861',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Tech-support',relationship='Own-child',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='25',native_country,income='United-States')>
# <Adult(age='55', workclass='Private', fnlwgt='144071',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Tech-support',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='18',native_country,income='United-States')>
# <Adult(age='58', workclass='Private', fnlwgt='186385',education='Doctorate',educationNum='16',marital_status='Never-married',occupation='Prof-specialty',relationship='Not-in-family',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='8',native_country,income='United-States')>
# <Adult(age='17', workclass='Private', fnlwgt='151799',education='11th',educationNum='7',marital_status='Never-married',occupation='Other-service',relationship='Own-child',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='20',native_country,income='United-States')>
# <Adult(age='54', workclass='Private', fnlwgt='235693',education='11th',educationNum='7',marital_status='Divorced',occupation='Adm-clerical',relationship='Not-in-family',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='47', workclass='Private', fnlwgt='144844',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='48', workclass='Self-emp-inc', fnlwgt='38240',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Farming-fishing',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='30', workclass='Private', fnlwgt='366065',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Craft-repair',relationship='Unmarried',race='Black',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='28', workclass='Local-gov', fnlwgt='167536',education='Assoc-acdm',educationNum='12',marital_status='Widowed',occupation='Prof-specialty',relationship='Unmarried',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='50', workclass='Private', fnlwgt='93690',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Transport-moving',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='43', workclass='Private', fnlwgt='269015',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Machine-op-inspct',relationship='Husband',race='Black',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='Germany')>
# <Adult(age='53', workclass='Private', fnlwgt='81794',education='12th',educationNum='8',marital_status='Married-civ-spouse',occupation='Adm-clerical',relationship='Wife',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='46', workclass='Private', fnlwgt='332355',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Adm-clerical',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='26', workclass='Private', fnlwgt='57512',education='Assoc-voc',educationNum='11',marital_status='Never-married',occupation='Craft-repair',relationship='Own-child',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='48',native_country,income='United-States')>
# <Adult(age='31', workclass='Private', fnlwgt='354464',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Other-service',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='20', workclass='Private', fnlwgt='203240',education='Assoc-acdm',educationNum='12',marital_status='Never-married',occupation='Adm-clerical',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='30',native_country,income='United-States')>
# <Adult(age='44', workclass='Private', fnlwgt='195545',education='HS-grad',educationNum='9',marital_status='Divorced',occupation='Machine-op-inspct',relationship='Own-child',race='Black',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='30', workclass='State-gov', fnlwgt='137613',education='Masters',educationNum='14',marital_status='Married-civ-spouse',occupation='Prof-specialty',relationship='Husband',race='Asian-Pac-Islander',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='17',native_country,income='Taiwan')>
# <Adult(age='22', workclass='Private', fnlwgt='43646',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Own-child',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='35', workclass='Self-emp-not-inc', fnlwgt='381931',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Farming-fishing',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='55',native_country,income='United-States')>
# <Adult(age='56', workclass='Private', fnlwgt='282023',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Adm-clerical',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='43', workclass='Private', fnlwgt='160369',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Machine-op-inspct',relationship='Own-child',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='42', workclass='Private', fnlwgt='52781',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Prof-specialty',relationship='Husband',race='White',sex='Male',capital_gain='7688',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='25', workclass='Private', fnlwgt='218136',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Handlers-cleaners',relationship='Not-in-family',race='Black',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='Outlying-US(Guam-USVI-etc)')>
# <Adult(age='24', workclass='Private', fnlwgt='33088',education='11th',educationNum='7',marital_status='Never-married',occupation='Handlers-cleaners',relationship='Not-in-family',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='40', workclass='Private', fnlwgt='70645',education='Preschool',educationNum='1',marital_status='Never-married',occupation='Other-service',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='20',native_country,income='United-States')>
# <Adult(age='19', workclass='Private', fnlwgt='250818',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Adm-clerical',relationship='Not-in-family',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='37', workclass='Private', fnlwgt='243409',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Transport-moving',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='59', workclass='Private', fnlwgt='214865',education='HS-grad',educationNum='9',marital_status='Widowed',occupation='Exec-managerial',relationship='Unmarried',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='51', workclass='Private', fnlwgt='43354',education='11th',educationNum='7',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='59', workclass='Private', fnlwgt='117059',education='11th',educationNum='7',marital_status='Married-civ-spouse',occupation='Transport-moving',relationship='Husband',race='Amer-Indian-Eskimo',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='62', workclass='Private', fnlwgt='91433',education='10th',educationNum='6',marital_status='Divorced',occupation='Prof-specialty',relationship='Unmarried',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='20', workclass='Private', fnlwgt='55465',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Other-service',relationship='Own-child',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='35',native_country,income='United-States')>
# <Adult(age='48', workclass='Local-gov', fnlwgt='39464',education='Masters',educationNum='14',marital_status='Never-married',occupation='Prof-specialty',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='52',native_country,income='United-States')>
# <Adult(age='50', workclass='Private', fnlwgt='180607',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Adm-clerical',relationship='Own-child',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='31', workclass='Local-gov', fnlwgt='446358',education='Doctorate',educationNum='16',marital_status='Never-married',occupation='Prof-specialty',relationship='Not-in-family',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='50',native_country,income='Mexico')>
# <Adult(age='39', workclass='Private', fnlwgt='451059',education='9th',educationNum='5',marital_status='Married-civ-spouse',occupation='Handlers-cleaners',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='61', workclass='Self-emp-not-inc', fnlwgt='92178',education='11th',educationNum='7',marital_status='Married-civ-spouse',occupation='Other-service',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='48', workclass='State-gov', fnlwgt='120131',education='HS-grad',educationNum='9',marital_status='Divorced',occupation='Craft-repair',relationship='Own-child',race='White',sex='Male',capital_gain='8614',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='31', workclass='Private', fnlwgt='226756',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Adm-clerical',relationship='Own-child',race='Black',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='52', workclass='Private', fnlwgt='145081',education='7th-8th',educationNum='4',marital_status='Never-married',occupation='Machine-op-inspct',relationship='Not-in-family',race='Black',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='57', workclass='Private', fnlwgt='161097',education='HS-grad',educationNum='9',marital_status='Divorced',occupation='Sales',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='26',native_country,income='United-States')>
# <Adult(age='25', workclass='State-gov', fnlwgt='194954',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Other-service',relationship='Wife',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='15',native_country,income='United-States')>
# <Adult(age='31', workclass='Private', fnlwgt='186144',education='7th-8th',educationNum='4',marital_status='Never-married',occupation='Machine-op-inspct',relationship='Not-in-family',race='Other',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='Mexico')>
# <Adult(age='30', workclass='?', fnlwgt='157289',education='11th',educationNum='7',marital_status='Never-married',occupation='?',relationship='Unmarried',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='29', workclass='Private', fnlwgt='263005',education='Masters',educationNum='14',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='45',native_country,income='Germany')>
# <Adult(age='34', workclass='Private', fnlwgt='198091',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='72',native_country,income='United-States')>
# <Adult(age='27', workclass='Private', fnlwgt='209205',education='Bachelors',educationNum='13',marital_status='Never-married',occupation='Tech-support',relationship='Own-child',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='64', workclass='Local-gov', fnlwgt='158412',education='HS-grad',educationNum='9',marital_status='Widowed',occupation='Adm-clerical',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='43', workclass='Private', fnlwgt='281422',education='Assoc-acdm',educationNum='12',marital_status='Never-married',occupation='Adm-clerical',relationship='Not-in-family',race='Black',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='45',native_country,income='United-States')>
# <Adult(age='45', workclass='Private', fnlwgt='116360',education='HS-grad',educationNum='9',marital_status='Divorced',occupation='Other-service',relationship='Not-in-family',race='Black',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='35',native_country,income='United-States')>
# <Adult(age='32', workclass='Private', fnlwgt='281540',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Tech-support',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='58', workclass='Private', fnlwgt='205410',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='58', workclass='Private', fnlwgt='182123',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Machine-op-inspct',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='44',native_country,income='United-States')>
# <Adult(age='52', workclass='Private', fnlwgt='308764',education='Some-college',educationNum='10',marital_status='Divorced',occupation='Exec-managerial',relationship='Unmarried',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='36', workclass='Self-emp-inc', fnlwgt='184456',education='Bachelors',educationNum='13',marital_status='Never-married',occupation='Tech-support',relationship='Not-in-family',race='White',sex='Male',capital_gain='27828',capital_loss='0',hours_per_week='55',native_country,income='United-States')>
# <Adult(age='41', workclass='Private', fnlwgt='104892',education='Masters',educationNum='14',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='36', workclass='Private', fnlwgt='195385',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Transport-moving',relationship='Husband',race='Amer-Indian-Eskimo',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='48', workclass='Private', fnlwgt='198000',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Craft-repair',relationship='Unmarried',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='38',native_country,income='United-States')>
# <Adult(age='50', workclass='Private', fnlwgt='158284',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Machine-op-inspct',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='43', workclass='Local-gov', fnlwgt='117022',education='HS-grad',educationNum='9',marital_status='Married-spouse-absent',occupation='Farming-fishing',relationship='Unmarried',race='Black',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='50', workclass='Self-emp-not-inc', fnlwgt='167728',education='Doctorate',educationNum='16',marital_status='Married-civ-spouse',occupation='Prof-specialty',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='60',native_country,income='United-States')>
# <Adult(age='35', workclass='Private', fnlwgt='91839',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Other-service',relationship='Husband',race='Amer-Indian-Eskimo',sex='Male',capital_gain='7688',capital_loss='0',hours_per_week='20',native_country,income='United-States')>
# <Adult(age='47', workclass='Private', fnlwgt='586657',education='Masters',educationNum='14',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='Japan')>
# <Adult(age='46', workclass='State-gov', fnlwgt='29696',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Transport-moving',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='19', workclass='Private', fnlwgt='63814',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Adm-clerical',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='18',native_country,income='United-States')>
# <Adult(age='33', workclass='Private', fnlwgt='232475',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='63', workclass='State-gov', fnlwgt='109735',education='HS-grad',educationNum='9',marital_status='Divorced',occupation='Adm-clerical',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='38',native_country,income='United-States')>
# <Adult(age='36', workclass='Private', fnlwgt='163396',education='Assoc-voc',educationNum='11',marital_status='Married-civ-spouse',occupation='Prof-specialty',relationship='Wife',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='53', workclass='Private', fnlwgt='95519',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Prof-specialty',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='42',native_country,income='United-States')>
# <Adult(age='47', workclass='Federal-gov', fnlwgt='402975',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='Black',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='61', workclass='Private', fnlwgt='128831',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Machine-op-inspct',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='31', workclass='Private', fnlwgt='235389',education='7th-8th',educationNum='4',marital_status='Never-married',occupation='Handlers-cleaners',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='30',native_country,income='Portugal')>
# <Adult(age='27', workclass='Private', fnlwgt='209292',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Sales',relationship='Other-relative',race='Black',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='32',native_country,income='Dominican-Republic')>
# <Adult(age='36', workclass='Private', fnlwgt='180150',education='12th',educationNum='8',marital_status='Divorced',occupation='Handlers-cleaners',relationship='Not-in-family',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='19', workclass='Local-gov', fnlwgt='243960',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Sales',relationship='Own-child',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='16',native_country,income='United-States')>
# <Adult(age='28', workclass='Private', fnlwgt='119793',education='Assoc-voc',educationNum='11',marital_status='Divorced',occupation='Exec-managerial',relationship='Not-in-family',race='White',sex='Male',capital_gain='10520',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='56', workclass='State-gov', fnlwgt='110257',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Adm-clerical',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='32', workclass='State-gov', fnlwgt='104509',education='HS-grad',educationNum='9',marital_status='Divorced',occupation='Other-service',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='25',native_country,income='United-States')>
# <Adult(age='69', workclass='?', fnlwgt='28197',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='?',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='60',native_country,income='United-States')>
# <Adult(age='49', workclass='Private', fnlwgt='188330',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Sales',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='28', workclass='State-gov', fnlwgt='200775',education='Masters',educationNum='14',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Wife',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='62', workclass='Private', fnlwgt='209844',education='Some-college',educationNum='10',marital_status='Divorced',occupation='Adm-clerical',relationship='Unmarried',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='30',native_country,income='United-States')>
# <Adult(age='44', workclass='Private', fnlwgt='126701',education='HS-grad',educationNum='9',marital_status='Divorced',occupation='Craft-repair',relationship='Unmarried',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='25', workclass='Private', fnlwgt='197130',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Sales',relationship='Own-child',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='30',native_country,income='United-States')>
# <Adult(age='63', workclass='Private', fnlwgt='201631',education='9th',educationNum='5',marital_status='Married-civ-spouse',occupation='Farming-fishing',relationship='Husband',race='Black',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='46', workclass='State-gov', fnlwgt='107231',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='1740',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='22', workclass='Private', fnlwgt='210474',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Other-service',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='35', workclass='Private', fnlwgt='340110',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='1848',hours_per_week='70',native_country,income='United-States')>
# <Adult(age='20', workclass='Private', fnlwgt='219262',education='11th',educationNum='7',marital_status='Never-married',occupation='Craft-repair',relationship='Not-in-family',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='60',native_country,income='United-States')>
# <Adult(age='53', workclass='Local-gov', fnlwgt='549341',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Prof-specialty',relationship='Husband',race='Black',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='35',native_country,income='United-States')>
# <Adult(age='46', workclass='Private', fnlwgt='35961',education='Assoc-acdm',educationNum='12',marital_status='Divorced',occupation='Sales',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='25',native_country,income='Germany')>
# <Adult(age='40', workclass='Private', fnlwgt='198316',education='10th',educationNum='6',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='18', workclass='Private', fnlwgt='174394',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Other-service',relationship='Own-child',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='20',native_country,income='United-States')>
# <Adult(age='61', workclass='State-gov', fnlwgt='199495',education='12th',educationNum='8',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='56', workclass='Private', fnlwgt='250873',education='11th',educationNum='7',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='45',native_country,income='United-States')>
# <Adult(age='52', workclass='Private', fnlwgt='74024',education='Masters',educationNum='14',marital_status='Married-civ-spouse',occupation='Prof-specialty',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='45',native_country,income='United-States')>
# <Adult(age='58', workclass='?', fnlwgt='158611',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='?',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='26', workclass='Private', fnlwgt='433906',education='Assoc-acdm',educationNum='12',marital_status='Never-married',occupation='Other-service',relationship='Not-in-family',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='37', workclass='Private', fnlwgt='208358',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='35', workclass='Private', fnlwgt='276153',education='Bachelors',educationNum='13',marital_status='Never-married',occupation='Tech-support',relationship='Not-in-family',race='Asian-Pac-Islander',sex='Female',capital_gain='4650',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='23', workclass='Private', fnlwgt='240398',education='Bachelors',educationNum='13',marital_status='Never-married',occupation='Sales',relationship='Not-in-family',race='Black',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='15',native_country,income='United-States')>
# <Adult(age='44', workclass='Private', fnlwgt='181762',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Transport-moving',relationship='Husband',race='White',sex='Male',capital_gain='15024',capital_loss='0',hours_per_week='55',native_country,income='United-States')>
# <Adult(age='48', workclass='Private', fnlwgt='95661',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Adm-clerical',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='43',native_country,income='United-States')>
# <Adult(age='43', workclass='Private', fnlwgt='144778',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='44', workclass='Private', fnlwgt='33105',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='Amer-Indian-Eskimo',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='60', workclass='Self-emp-inc', fnlwgt='93272',education='7th-8th',educationNum='4',marital_status='Married-civ-spouse',occupation='Sales',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='60',native_country,income='United-States')>
# <Adult(age='73', workclass='Local-gov', fnlwgt='232871',education='7th-8th',educationNum='4',marital_status='Married-civ-spouse',occupation='Protective-serv',relationship='Husband',race='White',sex='Male',capital_gain='2228',capital_loss='0',hours_per_week='10',native_country,income='United-States')>
# <Adult(age='33', workclass='Self-emp-not-inc', fnlwgt='116539',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='46', workclass='Federal-gov', fnlwgt='297906',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Prof-specialty',relationship='Husband',race='Asian-Pac-Islander',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='30', workclass='Private', fnlwgt='347132',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Machine-op-inspct',relationship='Not-in-family',race='Black',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='34', workclass='Private', fnlwgt='175878',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Sales',relationship='Husband',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='42', workclass='Private', fnlwgt='213821',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='1887',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='28', workclass='Private', fnlwgt='161674',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Machine-op-inspct',relationship='Unmarried',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='66', workclass='State-gov', fnlwgt='162945',education='Prof-school',educationNum='15',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='Black',sex='Male',capital_gain='20051',capital_loss='0',hours_per_week='55',native_country,income='United-States')>
# <Adult(age='46', workclass='Private', fnlwgt='146919',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Adm-clerical',relationship='Wife',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='27', workclass='Private', fnlwgt='269354',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Sales',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='25',native_country,income='?')>
# <Adult(age='36', workclass='Private', fnlwgt='159016',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Machine-op-inspct',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='38',native_country,income='United-States')>
# <Adult(age='40', workclass='Private', fnlwgt='175398',education='Assoc-voc',educationNum='11',marital_status='Divorced',occupation='Prof-specialty',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='20',native_country,income='United-States')>
# <Adult(age='38', workclass='Private', fnlwgt='187870',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Prof-specialty',relationship='Husband',race='White',sex='Male',capital_gain='7298',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='42', workclass='Self-emp-not-inc', fnlwgt='352196',education='HS-grad',educationNum='9',marital_status='Separated',occupation='Other-service',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='22',native_country,income='United-States')>
# <Adult(age='57', workclass='Private', fnlwgt='109638',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='1672',hours_per_week='45',native_country,income='United-States')>
# <Adult(age='40', workclass='Private', fnlwgt='201495',education='Bachelors',educationNum='13',marital_status='Divorced',occupation='Protective-serv',relationship='Not-in-family',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='45',native_country,income='United-States')>
# <Adult(age='37', workclass='Private', fnlwgt='377798',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='3103',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='69', workclass='Private', fnlwgt='203313',education='HS-grad',educationNum='9',marital_status='Widowed',occupation='Other-service',relationship='Not-in-family',race='White',sex='Female',capital_gain='991',capital_loss='0',hours_per_week='18',native_country,income='United-States')>
# <Adult(age='38', workclass='Private', fnlwgt='195686',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='35', workclass='Private', fnlwgt='176123',education='10th',educationNum='6',marital_status='Married-civ-spouse',occupation='Other-service',relationship='Husband',race='Asian-Pac-Islander',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='60',native_country,income='India')>
# <Adult(age='34', workclass='Private', fnlwgt='180284',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Handlers-cleaners',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='40', workclass='Private', fnlwgt='138975',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='56',native_country,income='United-States')>
# <Adult(age='32', workclass='Private', fnlwgt='116365',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Adm-clerical',relationship='Wife',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='20',native_country,income='United-States')>
# <Adult(age='46', workclass='Private', fnlwgt='214955',education='5th-6th',educationNum='3',marital_status='Divorced',occupation='Craft-repair',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='2339',hours_per_week='45',native_country,income='United-States')>
# <Adult(age='74', workclass='Private', fnlwgt='161387',education='HS-grad',educationNum='9',marital_status='Divorced',occupation='Handlers-cleaners',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='16',native_country,income='United-States')>
# <Adult(age='33', workclass='Private', fnlwgt='26973',education='Assoc-voc',educationNum='11',marital_status='Married-civ-spouse',occupation='Tech-support',relationship='Wife',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='45', workclass='Private', fnlwgt='156117',education='Assoc-voc',educationNum='11',marital_status='Divorced',occupation='Prof-specialty',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='32',native_country,income='United-States')>
# <Adult(age='40', workclass='Private', fnlwgt='104196',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Prof-specialty',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='1887',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='22', workclass='Private', fnlwgt='32616',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Other-service',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='30',native_country,income='United-States')>
# <Adult(age='64', workclass='Local-gov', fnlwgt='182866',education='HS-grad',educationNum='9',marital_status='Widowed',occupation='Other-service',relationship='Unmarried',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='24', workclass='Private', fnlwgt='218678',education='Bachelors',educationNum='13',marital_status='Never-married',occupation='Sales',relationship='Own-child',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='49', workclass='Self-emp-inc', fnlwgt='306289',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='28', workclass='Private', fnlwgt='173611',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Exec-managerial',relationship='Own-child',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='42', workclass='Private', fnlwgt='247695',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Machine-op-inspct',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='45',native_country,income='United-States')>
# <Adult(age='21', workclass='Private', fnlwgt='176262',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Exec-managerial',relationship='Own-child',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='30',native_country,income='United-States')>
# <Adult(age='31', workclass='Self-emp-not-inc', fnlwgt='325355',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Wife',race='White',sex='Female',capital_gain='0',capital_loss='1902',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='25', workclass='Private', fnlwgt='108301',education='HS-grad',educationNum='9',marital_status='Separated',occupation='Other-service',relationship='Unmarried',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='20',native_country,income='United-States')>
# <Adult(age='56', workclass='Self-emp-not-inc', fnlwgt='258752',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='60',native_country,income='United-States')>
# <Adult(age='34', workclass='Local-gov', fnlwgt='236415',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Adm-clerical',relationship='Unmarried',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='18',native_country,income='United-States')>
# <Adult(age='20', workclass='Private', fnlwgt='212582',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Other-service',relationship='Own-child',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='16',native_country,income='United-States')>
# <Adult(age='43', workclass='Private', fnlwgt='75742',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Transport-moving',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='45',native_country,income='United-States')>
# <Adult(age='32', workclass='Local-gov', fnlwgt='84119',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='20', workclass='Private', fnlwgt='146538',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Machine-op-inspct',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# ...
# <Adult(age='48', workclass='Self-emp-not-inc', fnlwgt='121124',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Prof-specialty',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='35',native_country,income='United-States')>
# <Adult(age='36', workclass='Self-emp-not-inc', fnlwgt='188972',education='Doctorate',educationNum='16',marital_status='Separated',occupation='Prof-specialty',relationship='Unmarried',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='10',native_country,income='Canada')>
# <Adult(age='20', workclass='Private', fnlwgt='197496',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Sales',relationship='Own-child',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='30',native_country,income='?')>
# <Adult(age='43', workclass='Private', fnlwgt='58447',education='Doctorate',educationNum='16',marital_status='Married-civ-spouse',occupation='Prof-specialty',relationship='Husband',race='White',sex='Male',capital_gain='99999',capital_loss='0',hours_per_week='55',native_country,income='United-States')>
# <Adult(age='33', workclass='Private', fnlwgt='69311',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Handlers-cleaners',relationship='Not-in-family',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='51', workclass='Local-gov', fnlwgt='153908',education='Masters',educationNum='14',marital_status='Divorced',occupation='Exec-managerial',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='31', workclass='Private', fnlwgt='220066',education='Bachelors',educationNum='13',marital_status='Never-married',occupation='Exec-managerial',relationship='Not-in-family',race='White',sex='Female',capital_gain='14344',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='44', workclass='Private', fnlwgt='128676',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Adm-clerical',relationship='Not-in-family',race='Black',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='37', workclass='Private', fnlwgt='200374',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Sales',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='1902',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='57', workclass='Private', fnlwgt='298507',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Prof-specialty',relationship='Husband',race='White',sex='Male',capital_gain='3103',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='20', workclass='Private', fnlwgt='653574',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Other-service',relationship='Own-child',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='33',native_country,income='El-Salvador')>
# <Adult(age='55', workclass='Federal-gov', fnlwgt='88876',education='Masters',educationNum='14',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='Asian-Pac-Islander',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='60',native_country,income='United-States')>
# <Adult(age='65', workclass='Private', fnlwgt='469602',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Sales',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='15',native_country,income='United-States')>
# <Adult(age='25', workclass='Private', fnlwgt='282612',education='Assoc-voc',educationNum='11',marital_status='Never-married',occupation='Tech-support',relationship='Unmarried',race='Black',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='32', workclass='Private', fnlwgt='143604',education='HS-grad',educationNum='9',marital_status='Divorced',occupation='Other-service',relationship='Not-in-family',race='Black',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='16',native_country,income='United-States')>
# <Adult(age='32', workclass='Private', fnlwgt='116539',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='1887',hours_per_week='55',native_country,income='United-States')>
# <Adult(age='34', workclass='Self-emp-inc', fnlwgt='242984',education='Bachelors',educationNum='13',marital_status='Never-married',occupation='Exec-managerial',relationship='Not-in-family',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='19', workclass='?', fnlwgt='242001',education='Some-college',educationNum='10',marital_status='Never-married',occupation='?',relationship='Own-child',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='18', workclass='Private', fnlwgt='181755',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Sales',relationship='Not-in-family',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='30',native_country,income='United-States')>
# <Adult(age='26', workclass='Private', fnlwgt='136226',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Craft-repair',relationship='Own-child',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='24', workclass='State-gov', fnlwgt='273905',education='Assoc-acdm',educationNum='12',marital_status='Married-civ-spouse',occupation='Protective-serv',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='27', workclass='?', fnlwgt='60726',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='?',relationship='Own-child',race='Black',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='47', workclass='Private', fnlwgt='102771',education='7th-8th',educationNum='4',marital_status='Married-civ-spouse',occupation='Handlers-cleaners',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='Portugal')>
# <Adult(age='53', workclass='Private', fnlwgt='233165',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='60',native_country,income='United-States')>
# <Adult(age='50', workclass='?', fnlwgt='146015',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='?',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='49', workclass='Self-emp-not-inc', fnlwgt='127921',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='20', workclass='Private', fnlwgt='194630',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Adm-clerical',relationship='Husband',race='White',sex='Male',capital_gain='3781',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='19', workclass='Private', fnlwgt='258633',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Adm-clerical',relationship='Own-child',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='25',native_country,income='?')>
# <Adult(age='54', workclass='?', fnlwgt='133963',education='HS-grad',educationNum='9',marital_status='Widowed',occupation='?',relationship='Own-child',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='47', workclass='Local-gov', fnlwgt='154940',education='Masters',educationNum='14',marital_status='Never-married',occupation='Prof-specialty',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='45',native_country,income='United-States')>
# <Adult(age='49', workclass='Private', fnlwgt='82649',education='Bachelors',educationNum='13',marital_status='Married-civ-spouse',occupation='Prof-specialty',relationship='Husband',race='White',sex='Male',capital_gain='5013',capital_loss='0',hours_per_week='45',native_country,income='United-States')>
# <Adult(age='47', workclass='Local-gov', fnlwgt='51579',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Protective-serv',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='50', workclass='Private', fnlwgt='209464',education='HS-grad',educationNum='9',marital_status='Separated',occupation='Other-service',relationship='Unmarried',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='35',native_country,income='United-States')>
# <Adult(age='62', workclass='?', fnlwgt='182687',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='?',relationship='Wife',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='45',native_country,income='United-States')>
# <Adult(age='43', workclass='Private', fnlwgt='132393',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Handlers-cleaners',relationship='Own-child',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='Poland')>
# <Adult(age='19', workclass='Private', fnlwgt='517036',education='HS-grad',educationNum='9',marital_status='Divorced',occupation='Craft-repair',relationship='Not-in-family',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='El-Salvador')>
# <Adult(age='35', workclass='Private', fnlwgt='244803',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Handlers-cleaners',relationship='Other-relative',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='Peru')>
# <Adult(age='36', workclass='Private', fnlwgt='114605',education='Assoc-voc',educationNum='11',marital_status='Married-civ-spouse',occupation='Adm-clerical',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='28', workclass='Private', fnlwgt='65171',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Tech-support',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='70',native_country,income='United-States')>
# <Adult(age='46', workclass='Private', fnlwgt='149949',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='48', workclass='Private', fnlwgt='204629',education='Masters',educationNum='14',marital_status='Married-civ-spouse',occupation='Exec-managerial',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='43', workclass='Private', fnlwgt='191547',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Farming-fishing',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='Mexico')>
# <Adult(age='32', workclass='Private', fnlwgt='158002',education='Some-college',educationNum='10',marital_status='Never-married',occupation='Machine-op-inspct',relationship='Other-relative',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='55',native_country,income='Ecuador')>
# <Adult(age='40', workclass='Self-emp-not-inc', fnlwgt='26892',education='Bachelors',educationNum='13',marital_status='Married-AF-spouse',occupation='Prof-specialty',relationship='Husband',race='White',sex='Male',capital_gain='7298',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='36', workclass='Private', fnlwgt='111545',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='70',native_country,income='United-States')>
# <Adult(age='43', workclass='Private', fnlwgt='117037',education='11th',educationNum='7',marital_status='Married-civ-spouse',occupation='Transport-moving',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='2042',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='46', workclass='Local-gov', fnlwgt='359193',education='Some-college',educationNum='10',marital_status='Divorced',occupation='Adm-clerical',relationship='Unmarried',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='45',native_country,income='United-States')>
# <Adult(age='29', workclass='Private', fnlwgt='217200',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='27', workclass='Private', fnlwgt='77774',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Machine-op-inspct',relationship='Own-child',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='34',native_country,income='United-States')>
# <Adult(age='31', workclass='Private', fnlwgt='97453',education='HS-grad',educationNum='9',marital_status='Divorced',occupation='Exec-managerial',relationship='Unmarried',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='19', workclass='Private', fnlwgt='206777',education='HS-grad',educationNum='9',marital_status='Never-married',occupation='Handlers-cleaners',relationship='Other-relative',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>
# <Adult(age='42', workclass='Private', fnlwgt='147251',education='Some-college',educationNum='10',marital_status='Married-civ-spouse',occupation='Prof-specialty',relationship='Wife',race='White',sex='Female',capital_gain='0',capital_loss='0',hours_per_week='36',native_country,income='United-States')>
# <Adult(age='47', workclass='Private', fnlwgt='120131',education='HS-grad',educationNum='9',marital_status='Married-civ-spouse',occupation='Craft-repair',relationship='Husband',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='50',native_country,income='United-States')>
# <Adult(age='22', workclass='?', fnlwgt='174626',education='7th-8th',educationNum='4',marital_status='Never-married',occupation='?',relationship='Own-child',race='White',sex='Male',capital_gain='0',capital_loss='0',hours_per_week='40',native_country,income='United-States')>

# %%
# Q2. Write two basic update queries
# First Update Query-Updating the marital status of all the persons having age 50 

# Printing the records of persons aging 50
for adult in session.query(Adult).filter_by(age=50):
     print(adult.age,adult.marital_status) 
        
# Updating the marital status as married
session.query(Adult).filter(Adult.age==50).update({'marital_status': 'Married'})

print("-"*80,"\n AFTER UPDATION\n","-"*80)

# Printing the updated records
for adult in session.query(Adult).filter_by(age=50):
     print(adult.age,adult.marital_status)
# Out:
# 50 Married-civ-spouse
# 50 Never-married
# 50 Married-civ-spouse
# 50 Married-civ-spouse
# 50 Married-civ-spouse
# 50 Married-civ-spouse
# 50 Separated
# --------------------------------------------------------------------------------
#  AFTER UPDATION
#  --------------------------------------------------------------------------------
# 50 Married
# 50 Married
# 50 Married
# 50 Married
# 50 Married
# 50 Married
# 50 Married

# %%
# Second Update Query - Updating the race of persons hailing from Mexico
# Printing the records of people hailing from  Mexico
for adult in session.query(Adult).filter_by(native_country='Mexico'):
     print(adult.race,adult.native_country) 
        
# Updating the race as Black
session.query(Adult).filter(Adult.native_country=='Mexico').update({'race': 'Black'})

print("-"*80,"\n AFTER UPDATION\n","-"*80)

# Printing the updated records
for adult in session.query(Adult).filter_by(native_country='Mexico'):
     print(adult.race,adult.native_country)
# Out:
# White Mexico
# Other Mexico
# White Mexico
# White Mexico
# White Mexico
# --------------------------------------------------------------------------------
#  AFTER UPDATION
#  --------------------------------------------------------------------------------
# Black Mexico
# Black Mexico
# Black Mexico
# Black Mexico
# Black Mexico

# %%
# Q3. Write two delete queries

# I- Deleting the records of people holding a doctorate
for adult in session.query(Adult).filter_by(education='Doctorate'):
     print(adult.age,adult.education,adult.workclass)
        
session.query(Adult).filter_by(education='Doctorate').delete()        

print("-"*80,"\n AFTER DELETION\n","-"*80)

# Trying to print After Deletion
for adult in session.query(Adult).filter_by(education='Doctorate'):
     print(adult.age,adult.education,adult.workclass)
# Out:
# 58 Doctorate Private
# 31 Doctorate Local-gov
# 50 Doctorate Self-emp-not-inc
# 36 Doctorate Self-emp-not-inc
# 43 Doctorate Private
# --------------------------------------------------------------------------------
#  AFTER DELETION
#  --------------------------------------------------------------------------------

# %%
# II - Deleting the records of persons having the age of 17
for adult in session.query(Adult).filter_by(age=17):
     print(adult.age,adult.sex,adult.native_country)
        
session.query(Adult).filter_by(age=17).delete()        

print("-"*80,"\n AFTER DELETION\n","-"*80)

# Trying to print After Deletion
for adult in session.query(Adult).filter_by(age=17):
     print(adult.age,adult.sex,adult.native_country)
# Out:
# 17 Female United-States
# --------------------------------------------------------------------------------
#  AFTER DELETION
#  --------------------------------------------------------------------------------

# %%
# Q4. Write two filter queries

# I. Filtering all the people woking in  the private sector
for adult in session.query(Adult).filter(Adult.workclass =='Private'):
    print(adult.age,adult.workclass,adult.sex,adult.education,adult.native_country)
# Out:
# 22 Private Male Some-college United-States
# 18 Private Female HS-grad United-States
# 45 Private Male Bachelors United-States
# 55 Private Male HS-grad United-States
# 28 Private Male Bachelors United-States
# 23 Private Male Some-college United-States
# 55 Private Male Bachelors United-States
# 54 Private Male 11th United-States
# 47 Private Male HS-grad United-States
# 30 Private Male Some-college United-States
# 50 Private Male HS-grad United-States
# 43 Private Male HS-grad Germany
# 53 Private Female 12th United-States
# 46 Private Male Some-college United-States
# 26 Private Male Assoc-voc United-States
# 31 Private Male HS-grad United-States
# 20 Private Female Assoc-acdm United-States
# 44 Private Female HS-grad United-States
# 22 Private Male HS-grad United-States
# 56 Private Male HS-grad United-States
# 43 Private Male HS-grad United-States
# 42 Private Male Bachelors United-States
# 25 Private Male Some-college Outlying-US(Guam-USVI-etc)
# 24 Private Male 11th United-States
# 40 Private Female Preschool United-States
# 19 Private Male Some-college United-States
# 37 Private Male HS-grad United-States
# 59 Private Female HS-grad United-States
# 51 Private Male 11th United-States
# 59 Private Male 11th United-States
# 62 Private Female 10th United-States
# 20 Private Male HS-grad United-States
# 50 Private Female HS-grad United-States
# 39 Private Male 9th United-States
# 31 Private Male HS-grad United-States
# 52 Private Female 7th-8th United-States
# 57 Private Female HS-grad United-States
# 31 Private Female 7th-8th Mexico
# 29 Private Male Masters Germany
# 34 Private Male HS-grad United-States
# 27 Private Male Bachelors United-States
# 43 Private Female Assoc-acdm United-States
# 45 Private Female HS-grad United-States
# 32 Private Male Some-college United-States
# 58 Private Male HS-grad United-States
# 58 Private Male HS-grad United-States
# 52 Private Female Some-college United-States
# 41 Private Male Masters United-States
# 36 Private Male HS-grad United-States
# 48 Private Female Some-college United-States
# 50 Private Male Some-college United-States
# 35 Private Male Bachelors United-States
# 47 Private Male Masters Japan
# 19 Private Female Some-college United-States
# 33 Private Male HS-grad United-States
# 36 Private Female Assoc-voc United-States
# 53 Private Male HS-grad United-States
# 61 Private Male HS-grad United-States
# 31 Private Female 7th-8th Portugal
# 27 Private Female HS-grad Dominican-Republic
# 36 Private Male 12th United-States
# 28 Private Male Assoc-voc United-States
# 49 Private Male HS-grad United-States
# 62 Private Female Some-college United-States
# 44 Private Male HS-grad United-States
# 25 Private Female HS-grad United-States
# 63 Private Male 9th United-States
# 22 Private Female HS-grad United-States
# 35 Private Male Bachelors United-States
# 20 Private Male 11th United-States
# 46 Private Female Assoc-acdm Germany
# 40 Private Male 10th United-States
# 18 Private Female HS-grad United-States
# 56 Private Male 11th United-States
# 52 Private Male Masters United-States
# 26 Private Male Assoc-acdm United-States
# 37 Private Male HS-grad United-States
# 35 Private Female Bachelors United-States
# 23 Private Male Bachelors United-States
# 44 Private Male Bachelors United-States
# 48 Private Female Some-college United-States
# 43 Private Male HS-grad United-States
# 44 Private Male HS-grad United-States
# 30 Private Female Some-college United-States
# 34 Private Female HS-grad United-States
# 42 Private Male HS-grad United-States
# 28 Private Female HS-grad United-States
# 46 Private Female HS-grad United-States
# 27 Private Male Bachelors ?
# 36 Private Male HS-grad United-States
# 40 Private Female Assoc-voc United-States
# 38 Private Male Bachelors United-States
# 57 Private Male Some-college United-States
# 40 Private Male Bachelors United-States
# 37 Private Male Some-college United-States
# 69 Private Female HS-grad United-States
# 38 Private Male Some-college United-States
# 35 Private Male 10th India
# 34 Private Male Some-college United-States
# 40 Private Male HS-grad United-States
# 32 Private Female HS-grad United-States
# 46 Private Female 5th-6th United-States
# 74 Private Female HS-grad United-States
# 33 Private Female Assoc-voc United-States
# 45 Private Female Assoc-voc United-States
# 40 Private Male Bachelors United-States
# 22 Private Female Some-college United-States
# 24 Private Male Bachelors United-States
# 28 Private Female HS-grad United-States
# 42 Private Male HS-grad United-States
# 21 Private Female Some-college United-States
# 25 Private Female HS-grad United-States
# 20 Private Female Some-college United-States
# 43 Private Male Some-college United-States
# 20 Private Male HS-grad United-States
# 42 Private Male Bachelors United-States
# 18 Private Female Some-college United-States
# 49 Private Female Some-college United-States
# 21 Private Male Some-college United-States
# 25 Private Male Some-college United-States
# 26 Private Male Bachelors South
# 54 Private Female Bachelors United-States
# 47 Private Female Some-college United-States
# 22 Private Male Assoc-voc United-States
# 41 Private Female 5th-6th Mexico
# 25 Private Male Bachelors United-States
# 36 Private Male 11th United-States
# 26 Private Male HS-grad United-States
# 24 Private Female Some-college United-States
# 33 Private Female Some-college United-States
# 27 Private Male Some-college United-States
# 56 Private Male Masters United-States
# 19 Private Female Some-college United-States
# 44 Private Female Bachelors United-States
# 38 Private Male Assoc-voc United-States
# 36 Private Male Some-college United-States
# 45 Private Male 5th-6th Mexico
# 25 Private Male HS-grad United-States
# 32 Private Female Masters United-States
# 29 Private Female HS-grad Laos
# 44 Private Female Bachelors United-States
# 20 Private Male Some-college ?
# 33 Private Male HS-grad United-States
# 31 Private Female Bachelors United-States
# 44 Private Female Some-college United-States
# 37 Private Male Bachelors United-States
# 57 Private Male Bachelors United-States
# 20 Private Male Some-college El-Salvador
# 65 Private Male Bachelors United-States
# 25 Private Female Assoc-voc United-States
# 32 Private Female HS-grad United-States
# 32 Private Male Bachelors United-States
# 18 Private Male HS-grad United-States
# 26 Private Male HS-grad United-States
# 47 Private Male 7th-8th Portugal
# 53 Private Male HS-grad United-States
# 20 Private Male HS-grad United-States
# 19 Private Female Some-college ?
# 49 Private Male Bachelors United-States
# 50 Private Female HS-grad United-States
# 43 Private Male HS-grad Poland
# 19 Private Female HS-grad El-Salvador
# 35 Private Male HS-grad Peru
# 36 Private Male Assoc-voc United-States
# 28 Private Male Some-college United-States
# 46 Private Male Some-college United-States
# 48 Private Male Masters United-States
# 43 Private Male HS-grad Mexico
# 32 Private Male Some-college Ecuador
# 36 Private Male HS-grad United-States
# 43 Private Male 11th United-States
# 29 Private Male HS-grad United-States
# 27 Private Female HS-grad United-States
# 31 Private Female HS-grad United-States
# 19 Private Male HS-grad United-States
# 42 Private Female Some-college United-States
# 47 Private Male HS-grad United-States

# %%
from sqlalchemy import and_
# II. Filtering the females working having masters degree
for adult in session.query(Adult).filter(and_(Adult.sex =='Female',Adult.education =='Masters')):
    print(adult.age,adult.sex,adult.education,adult.workclass,adult.race,adult.native_country,adult.hours_per_week)
# Out:
# 48 Female Masters Local-gov White United-States 52
# 28 Female Masters State-gov White United-States 40
# 32 Female Masters Private White United-States 20
# 51 Female Masters Local-gov White United-States 40
# 47 Female Masters Local-gov White United-States 45

# %%
# Q5. Write two function queries
from sqlalchemy import func

# I- Function-Count of the people holding a bachelors degree 
print("Count of people having Bachelors Degree:")
for masters_count in session.query(func.count(Adult.index)).filter_by(education='Bachelors'):
    print(masters_count)

# II- Function-Avg hours_per_work of all the females employed in the Private sector    
for avg_age in session.query(func.avg(Adult.hours_per_week)).filter(and_(Adult.sex =='Female',Adult.workclass =='Private')):
    print("\nAverage work hours of all females employed in the private sector:" ,avg_age)
# Out:
# Count of people having Bachelors Degree:
# (37,)
#
# Average work hours of all females employed in the private sector: (33.96875,)
